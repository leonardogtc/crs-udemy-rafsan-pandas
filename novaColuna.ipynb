# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20230101', periods = 90, freq = "D")

# %%
df = pd.DataFrame(np.random.randn(90,5), index = datas, columns = list("ABCDE"))

# %%
df
# Out:
#                    A         B         C         D         E
# 2023-01-01  1.172574  1.846811  0.336453 -1.431069 -0.074585
# 2023-01-02  2.378327 -0.273694 -0.178892  0.286559  0.460601
# 2023-01-03  0.595379  1.446933 -1.729488  1.272774 -0.228311
# 2023-01-04  0.392613  1.665932 -0.910679  1.425704 -0.813994
# 2023-01-05  1.562471  0.456131 -1.029322  0.423648 -1.226093
# ...              ...       ...       ...       ...       ...
# 2023-03-27  0.025982 -0.198974 -1.557302 -0.823250 -0.565153
# 2023-03-28  1.567445  2.342003  0.444802 -0.335856 -1.013509
# 2023-03-29  0.296540  0.788955 -0.407562 -0.313783  0.080301
# 2023-03-30  1.420833 -1.033213 -0.063409  1.811447  0.361880
# 2023-03-31 -0.001693  0.243051  0.089007 -0.633423 -0.513221
#
# [90 rows x 5 columns]

# %%
# Adicionar uma nova coluna ao dataframe
df['F'] = 1

# %%
df.head(10)
# Out:
#                    A         B         C         D         E  F
# 2023-01-01  1.172574  1.846811  0.336453 -1.431069 -0.074585  1
# 2023-01-02  2.378327 -0.273694 -0.178892  0.286559  0.460601  1
# 2023-01-03  0.595379  1.446933 -1.729488  1.272774 -0.228311  1
# 2023-01-04  0.392613  1.665932 -0.910679  1.425704 -0.813994  1
# 2023-01-05  1.562471  0.456131 -1.029322  0.423648 -1.226093  1
# 2023-01-06 -0.825204 -0.010998  1.311059 -1.058872 -0.540590  1
# 2023-01-07  1.791880 -1.299890 -1.614869 -1.550356 -1.546562  1
# 2023-01-08 -0.290128 -0.363714  0.764810  0.684446  0.146411  1
# 2023-01-09 -1.566570 -2.306144  0.146832 -1.324712  0.501884  1
# 2023-01-10 -0.589573  1.578934 -0.151192  1.539495  0.977232  1

# %%
df['Produtos'] = df['A'] * df['B']

# %%
df
# Out:
#                    A         B         C         D         E  F  Produtos
# 2023-01-01  1.172574  1.846811  0.336453 -1.431069 -0.074585  1  2.165522
# 2023-01-02  2.378327 -0.273694 -0.178892  0.286559  0.460601  1 -0.650934
# 2023-01-03  0.595379  1.446933 -1.729488  1.272774 -0.228311  1  0.861473
# 2023-01-04  0.392613  1.665932 -0.910679  1.425704 -0.813994  1  0.654067
# 2023-01-05  1.562471  0.456131 -1.029322  0.423648 -1.226093  1  0.712692
# ...              ...       ...       ...       ...       ... ..       ...
# 2023-03-27  0.025982 -0.198974 -1.557302 -0.823250 -0.565153  1 -0.005170
# 2023-03-28  1.567445  2.342003  0.444802 -0.335856 -1.013509  1  3.670960
# 2023-03-29  0.296540  0.788955 -0.407562 -0.313783  0.080301  1  0.233957
# 2023-03-30  1.420833 -1.033213 -0.063409  1.811447  0.361880  1 -1.468024
# 2023-03-31 -0.001693  0.243051  0.089007 -0.633423 -0.513221  1 -0.000412
#
# [90 rows x 7 columns]

# %%
df['Posicao'] = range(90)

# %%
df
# Out:
#                    A         B         C         D         E  F  Produtos  \
# 2023-01-01  1.172574  1.846811  0.336453 -1.431069 -0.074585  1  2.165522
# 2023-01-02  2.378327 -0.273694 -0.178892  0.286559  0.460601  1 -0.650934
# 2023-01-03  0.595379  1.446933 -1.729488  1.272774 -0.228311  1  0.861473
# 2023-01-04  0.392613  1.665932 -0.910679  1.425704 -0.813994  1  0.654067
# 2023-01-05  1.562471  0.456131 -1.029322  0.423648 -1.226093  1  0.712692
# ...              ...       ...       ...       ...       ... ..       ...
# 2023-03-27  0.025982 -0.198974 -1.557302 -0.823250 -0.565153  1 -0.005170
# 2023-03-28  1.567445  2.342003  0.444802 -0.335856 -1.013509  1  3.670960
# 2023-03-29  0.296540  0.788955 -0.407562 -0.313783  0.080301  1  0.233957
# 2023-03-30  1.420833 -1.033213 -0.063409  1.811447  0.361880  1 -1.468024
# 2023-03-31 -0.001693  0.243051  0.089007 -0.633423 -0.513221  1 -0.000412
#
#             Posicao
# 2023-01-01        0
# 2023-01-02        1
# ...

# %%
# Substituir todos os valores
# de uma coluna por um valor único
df['F'] = 88

# %%
df
# Out:
#                    A         B         C         D         E   F  Produtos  \
# 2023-01-01  1.172574  1.846811  0.336453 -1.431069 -0.074585  88  2.165522
# 2023-01-02  2.378327 -0.273694 -0.178892  0.286559  0.460601  88 -0.650934
# 2023-01-03  0.595379  1.446933 -1.729488  1.272774 -0.228311  88  0.861473
# 2023-01-04  0.392613  1.665932 -0.910679  1.425704 -0.813994  88  0.654067
# 2023-01-05  1.562471  0.456131 -1.029322  0.423648 -1.226093  88  0.712692
# ...              ...       ...       ...       ...       ...  ..       ...
# 2023-03-27  0.025982 -0.198974 -1.557302 -0.823250 -0.565153  88 -0.005170
# 2023-03-28  1.567445  2.342003  0.444802 -0.335856 -1.013509  88  3.670960
# 2023-03-29  0.296540  0.788955 -0.407562 -0.313783  0.080301  88  0.233957
# 2023-03-30  1.420833 -1.033213 -0.063409  1.811447  0.361880  88 -1.468024
# 2023-03-31 -0.001693  0.243051  0.089007 -0.633423 -0.513221  88 -0.000412
#
#             Posicao
# 2023-01-01        0
# 2023-01-02        1
# ...
