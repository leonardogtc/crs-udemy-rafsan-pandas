# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardogtc/udemy-analise-de-dados-pandas/blob/main/dataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series([7,4,2,np.nan,6,9])

# %%
series

# %%
type(series)

# %%
datas = pd.date_range('20230101', periods = 6, freq = "D")

# %%
datas

# %%
np.random.randn(6,4) # Gera números aleatórios com desvio padrão normal

# %%
list("ABCD") # Gerar uma lista de dados

# %%
df = pd.DataFrame(np.random.randn(6,4), index = datas, columns = list("ABCD"))

# %%
df.dtypes # Mostra os tipos relacionados aos dados
df # Mostra a planilha de dados gerada
# Out:
#                    A         B         C         D
# 2023-01-01 -0.693522  1.150044 -0.880556  0.603354
# 2023-01-02  0.206691 -1.028231 -0.057357 -0.739694
# 2023-01-03  2.178562 -1.606155  0.843471  0.569093
# 2023-01-04 -0.308157 -1.773701  2.981304 -0.333408
# 2023-01-05 -1.914276 -0.275858 -0.027824 -1.391198
# 2023-01-06 -0.492848  0.455536  0.180965  2.940326

# %%
type(df)

# %%
from pandas.core.arrays import categorical
df2 = pd.DataFrame({'A': 7,
                    'B': pd.Timestamp('20230101'),
                    'C': pd.Series(1, index=list(range(4)), dtype=np.float32),
                    'D': np.array([3] * 4, dtype='int32'),
                    'E': pd.Categorical(["teste0","teste1","teste2","teste3"]),
                    'F': "Python"
                    })

# %%
df2
# Out:
#    A          B    C  D       E       F
# 0  7 2023-01-01  1.0  3  teste0  Python
# 1  7 2023-01-01  1.0  3  teste1  Python
# 2  7 2023-01-01  1.0  3  teste2  Python
# 3  7 2023-01-01  1.0  3  teste3  Python

# %%
df2.dtypes

# %% [markdown]
# Visualizando Dados

# %%
df.head(2)
# Out:
#                    A         B         C         D
# 2023-01-01 -0.693522  1.150044 -0.880556  0.603354
# 2023-01-02  0.206691 -1.028231 -0.057357 -0.739694

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2023-01-05 -1.914276 -0.275858 -0.027824 -1.391198
# 2023-01-06 -0.492848  0.455536  0.180965  2.940326

# %%
# Listando somente os index do dataframe
df.index
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Colunas
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# valores do dataframe
df.to_numpy()
# Out:
# array([[-0.6935225 ,  1.15004446, -0.88055575,  0.60335428],
#        [ 0.20669103, -1.02823125, -0.05735656, -0.73969357],
#        [ 2.1785622 , -1.60615479,  0.84347148,  0.5690934 ],
#        [-0.30815722, -1.77370104,  2.98130356, -0.33340764],
#        [-1.91427576, -0.27585818, -0.02782411, -1.39119837],
#        [-0.4928479 ,  0.45553619,  0.18096469,  2.94032581]])

# %%
# Transposta -
# Transforma linha em coluna
#  e coluna em linha
df.T
# Out:
#    2023-01-01  2023-01-02  2023-01-03  2023-01-04  2023-01-05  2023-01-06
# A   -0.693522    0.206691    2.178562   -0.308157   -1.914276   -0.492848
# B    1.150044   -1.028231   -1.606155   -1.773701   -0.275858    0.455536
# C   -0.880556   -0.057357    0.843471    2.981304   -0.027824    0.180965
# D    0.603354   -0.739694    0.569093   -0.333408   -1.391198    2.940326
